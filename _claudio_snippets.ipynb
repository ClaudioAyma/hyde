# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudioAyma/ClaudioAyma.github.io/blob/master/_claudio_snippets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #_Suma

# %%
def suma(a,b):
    return a + b

# %% [markdown]
# #_Resta

# %%
def resta(a,b):
    return a - b

# %% [markdown]
# #_Division

# %%
def division(a,b):
    return a / b
